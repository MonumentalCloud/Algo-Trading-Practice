# %%
from measures.value_trading import robust_value_data
from measures.momentum_strategy import hq_momentum_data

hqm_dataframe = hq_momentum_data()
rv_dataframe = robust_value_data()

# %%
hqm_dataframe.head()
# Out:
#   Ticker   Price Number of Shares to Buy One-Year Price Return  \
# 0      A  124.07                     n/a              0.413864
# 1    AAL   17.65                     n/a             -0.396115
# 2    AAP  163.03                     n/a             0.0172943
# 3   AAPL  126.22                     n/a              0.823475
# 4   ABBV  109.76                     n/a              0.264833
#
#   One-Year Return Percentile Six-Month Price Return  \
# 0                   0.871287               0.391984
# 1                  0.0277228              0.0187616
# 2                    0.39604               0.168809
# 3                   0.970297                0.45617
# 4                   0.752475               0.188779
#
#   Six-Month Return Percentile Three-Month Price Return  \
# 0                     0.79604                 0.204381
# 1                    0.120792                 0.324866
# 2                    0.374257                 0.022305
# 3                    0.861386                 0.098172
# 4                    0.417822                 0.205934
#
#   Three-Month Return Percentile One-Month Price Return  \
# 0                      0.621782              0.0860589
# 1                      0.843564               0.462398
# 2                       0.20396              0.0303805
# 3                       0.39604              0.0269606
# 4                      0.629703              0.0919794
#
#   One-Month Return Percentile HQM Score
# 0                    0.629703  0.729703
# 1                    0.978218  0.492574
# 2                    0.427723  0.350495
# 3                    0.407921  0.658911
# 4                    0.657426  0.614356

# %%
import pandas as pd
import numpy as np


my_columns = ['Ticker', 'HQM Score', 'Robust Value']
final_dataframe = hqm_dataframe[['Ticker','HQM Score']]
final_dataframe.loc[:,'Robust Value Score'] = rv_dataframe['Robust Value Score']
# Out:
# /opt/miniconda3/envs/myenv/lib/python3.9/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/miniconda3/envs/myenv/lib/python3.9/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
